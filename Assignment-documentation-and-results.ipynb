# %% [markdown]
# ## Assignment 1
#
# Based on the assignment, I have documented all the findings and results in this file so that it is easier to go through rather than going through every files modified.

# %% [markdown]
# ## Task 1
#
# For Task 1, I modified all the files taught by the professor by adding my own 'data.txt' file which contains a paragraph which is basically a summary of Harry Potter(It was generated using chatgpt which I converted into a txt file). The window size of 2 has been used in all the files modified. I am attaching the screenshots of the training results here.
#
# Skipgram training time and loss:
#
#  ![image.png](attachment:image.png)
#
# Skipgram(negative sampling):
#
# ![image-2.png](attachment:image-2.png)
#
#
# Glove:
#  ![image-3.png](attachment:image-3.png)
